# %%
from IPython.display import clear_output
import random
def display_board(board):
    clear_output()
    print('{}|{}|{}'.format(board[7],board[8],board[9]))
    print('-----')
    print('{}|{}|{}'.format(board[4],board[5],board[6]))
    print('-----')
    print('{}|{}|{}'.format(board[1],board[2],board[3]))

# %%
test_board = ['#','X','O','X','O','X','O','X','O','X']
display_board(test_board)
# Out:
# X|O|X
# -----
# O|X|O
# -----
# X|O|X

# %%
def player_input():
    marker = ''
    while marker not in ['X', 'O']:
        marker = input('Player 1, choose X or O: ').upper()
    player1 = marker
    player2 = 'O' if marker == 'X' else 'X'
    return (player1,player2)

# %%
player_input()
# Out:
# ('O', 'X')

# %%
def place_marker(board, marker, position):
    board[position] = marker
    return board

# %%
place_marker(test_board,'$',8)
display_board(test_board)
# Out:
# X|$|X
# -----
# O|X|O
# -----
# X|O|X

# %%
def win_check(board, mark):
    win = [mark,mark,mark]
    return board[1:4] == win \
            or board[4:7] == win \
            or board[7:10] == win \
            or board[1:8:3] == win \
            or board[2:9:3] == win \
            or board[3:10:3] == win \
            or board[1:10:4] == win \
            or board[3:8:2] == win

# %%
win_check(test_board,'O')
# Out:
# False

# %%
def choose_first():
    return random.randint(0,1)

# %%
def space_check(board, position):
    return board[position]==' '

# %%
def full_board_check(board):
    for i in range(1,10):
        if space_check(board, i):
            return False
    return True

# %%
full_board_check(test_board)
# Out:
# True

# %%
def player_choice(board):
    position = ''
    while True:
        position = input('Choose your next position: (1-9) ')
        if not position.isdigit() or not (1 <= int(position) <= 9):
            print ('Please choose a number between 1 and 9')
            continue
        position = int(position)
        if not space_check(board, position):
            print ('Position already chosen, pick a different one')
        else:
            return position

# %%
def replay():
    choice = ''
    while choice not in ['Y', 'N']:
        choice = input('Do you want to keep playing? (Y or N) ').upper()
    return choice == 'Y'

# %%
print('Welcome to Tic Tac Toe!')
while True:
    board = ['#',' ',' ',' ',' ',' ',' ',' ',' ',' ']
    players = player_input()
    round = choose_first()
    print('Player {} will go first'.format('1' if round == 0 else '2'))
    play_game = input('Ready to play? (Y or N) ').upper()
    game_on = play_game == 'Y'
    while game_on:
        display_board(board)
        position = player_choice(board)
        place_marker(board, players[round], position)
        if win_check(board, players[round]):
            display_board(board)
            print('Player {} has won!'.format('1' if round == 0 else '2'))
            game_on = False
        elif full_board_check(board):
            display_board(board)
            print('The game is a tie!')
            game_on = False
        round = (round + 1) % 2
    if not replay():
        break
# Out:
# X|X|O
# -----
# O|X|O
# -----
# X|O|O
