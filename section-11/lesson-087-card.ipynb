# %%
import random
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9,
    'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')

# %%
class Card():
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[self.rank]
    def __str__(self):
        return self.rank + ' of ' + self.suit

# %%
class Deck():
    def __init__(self):
        self.all_cards = []
        for suit in suits:
            for rank in ranks:
                created_card = Card(suit, rank)
                self.all_cards.append(created_card)
    def shuffle(self):
        random.shuffle(self.all_cards)
    def deal_one(self):
        return self.all_cards.pop()

# %%
class Player():
    def __init__(self,name):
        self.name = name
        self.all_cards = []
    def remove_one(self):
        return self.all_cards.pop(0)
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards'

# %%
# Game setup
war_cards = 5
max_rounds = 1000
player_one = Player('One')
player_two = Player('Two')
new_deck = Deck()
new_deck.shuffle()
for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())
game_on = True
round_num = 0
while game_on:
    round_num += 1
    if round_num > max_rounds:
        print(f'War not resolved in {max_rounds} rounds. Call a tie!')
        game_on = False
        break
    print(f'Currently on round {round_num}. Player One has {len(player_one.all_cards)} cards. Player Two has {len(player_two.all_cards)} cards')
    if len(player_one.all_cards) == 0:
        print('Player One, out of cards! Player Two wins!')
        game_on = False
        break
    if len(player_two.all_cards) == 0:
        print('Player Two, out of cards! Player One wins!')
        game_on = False
        break
    # Start a new round
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    at_war = True
    while at_war:
        card_one = player_one_cards[-1]
        card_two = player_two_cards[-1]
        print('Player One: "{}" vs. Player Two: "{}"'.format(card_one, card_two))
        if card_one.value > card_two.value:
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            at_war = False
        elif card_one.value < card_two.value:
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            at_war = False
        else:
            if len(player_one.all_cards) < war_cards:
                print('Player One, unable to declare war! Player Two wins!')
                game_on = False
                break
            elif len(player_two.all_cards) < war_cards:
                print('Player Two, unable to declare war! Player One wins!')
                game_on = False
                break
            else:
                for num in range(war_cards):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Currently on round 1. Player One has 26 cards. Player Two has 26 cards
# Player One: "Three of Hearts" vs. Player Two: "Nine of Hearts"
# Currently on round 2. Player One has 25 cards. Player Two has 27 cards
# Player One: "King of Clubs" vs. Player Two: "Ace of Diamonds"
# Currently on round 3. Player One has 24 cards. Player Two has 28 cards
# Player One: "Four of Spades" vs. Player Two: "Ten of Diamonds"
# Currently on round 4. Player One has 23 cards. Player Two has 29 cards
# Player One: "Seven of Hearts" vs. Player Two: "Eight of Diamonds"
# Currently on round 5. Player One has 22 cards. Player Two has 30 cards
# Player One: "Three of Clubs" vs. Player Two: "Eight of Hearts"
# Currently on round 6. Player One has 21 cards. Player Two has 31 cards
# Player One: "Eight of Clubs" vs. Player Two: "Two of Hearts"
# Currently on round 7. Player One has 22 cards. Player Two has 30 cards
# Player One: "Seven of Diamonds" vs. Player Two: "Five of Clubs"
# ...
