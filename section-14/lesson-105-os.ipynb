# %%
pwd
# Out:
# '/workspaces/python/section-14'

# %%
f = open('practice.txt', 'w')
f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# '/workspaces/python/section-14'

# %%
os.listdir('..')
# Out:
# ['section-05',
#  'section-03',
#  'section-08',
#  '.gitignore',
#  'section-10',
#  'section-07',
#  '.devcontainer',
#  '.git',
#  'section-14',
#  'section-09',
#  'section-06',
#  'section-13',
#  'section-11',
#  'section-12',
#  '.vscode',
#  'section-04']

# %%
import shutil

# %%
shutil.move('practice.txt', 'test.txt')
# Out:
# 'test.txt'

# %%
import send2trash

# %%
send2trash.send2trash('test.txt')

# %%
for folder,subfolders,files in os.walk('..'):
    print('Folder: ' + folder)
    print('Subfolders:' + subfolders.__str__())
    print('Files: ' + files.__str__())
    print('')
# Out:
# Folder: ..
# Subfolders:['section-05', 'section-03', 'section-08', 'section-10', 'section-07', '.Trash-1000', '.devcontainer', '.git', 'section-14', 'section-09', 'section-06', 'section-13', 'section-11', 'section-12', '.vscode', 'section-04']
# Files: ['.gitignore']
#
# Folder: ../section-05
# Subfolders:[]
# Files: ['lesson-037-operators.ipynb', 'lesson-036-while-loops.ipynb', 'lesson-038-list-comprehension.ipynb', 'lesson-035-for-loops.ipynb', 'lesson-039-assessment.ipynb', 'lesson-034-if.ipynb']
#
# Folder: ../section-03
# Subfolders:[]
# Files: ['lesson-015-strings.ipynb', 'lesson-018-string-formatting.ipynb', 'lesson-026-sets.ipynb', 'lesson-028-io.ipynb', 'lesson-012-numbers.ipynb', 'lesson-014-variables.ipynb', 'lesson-021-lists.ipynb', 'lesson-025-tuples.ipynb', 'lesson-017-strings-methods.ipynb', 'lesson-023-dictionaries.ipynb', 'lesson-030-assessment.ipynb', 'lesson-016-strings.ipynb', 'lesson-027-boolean.ipynb']
#
# Folder: ../section-08
# Subfolders:[]
# ...
